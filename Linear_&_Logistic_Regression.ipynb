# %% [markdown]
# <a href="https://colab.research.google.com/github/mackinitup/Project3/blob/master/Linear_%26_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
loansData = pd.read_csv("https://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv")

# %%
loansData.head()
# Out:
#        Amount.Requested  Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 81174             20000                     20000.0         8.90%   36 months
# 99592             19200                     19200.0        12.12%   36 months
# 80059             35000                     35000.0        21.98%   60 months
# 15825             10000                      9975.0         9.99%   36 months
# 33182             12000                     12000.0        11.71%   36 months
#
#              Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 81174  debt_consolidation               14.90%    SC       MORTGAGE
# 99592  debt_consolidation               28.36%    TX       MORTGAGE
# 80059  debt_consolidation               23.81%    CA       MORTGAGE
# 15825  debt_consolidation               14.30%    KS       MORTGAGE
# 33182         credit_card               18.78%    NJ           RENT
#
#        Monthly.Income FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# ...

# %%
intrate = ['Interest.Rate']

# %%
fico = ['FICO.Score']

# %%
p = plot(fico,intrate,'o')
ax = gca()
xt = ax.set_xlabel('FICO Score')
yt = ax.set_ylabel('Interest Rate %')

# %%
# %matplotlib inline

# %%
import pandas as pd
loansData = pd.read_csv('https://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv')

# %%
loansData['Interest.Rate'][0:5]
# Out:
# 81174     8.90%
# 99592    12.12%
# 80059    21.98%
# 15825     9.99%
# 33182    11.71%
# Name: Interest.Rate, dtype: object

# %%
loansData['Loan.Length'][0:5]
# Out:
# 81174    36 months
# 99592    36 months
# 80059    60 months
# 15825    36 months
# 33182    36 months
# Name: Loan.Length, dtype: object

# %%
loansData['FICO.Range'][0:5]
# Out:
# 81174    735-739
# 99592    715-719
# 80059    690-694
# 15825    695-699
# 33182    695-699
# Name: FICO.Range, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
plt.figure()
loansmin = pd.read_csv("https://raw.githubusercontent.com/nborwankar/LearnDataScience/master/datasets/loanf.csv")

# %%
fico = loansmin['FICO.Score']
p = fico.hist()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.figure()

# %%
loansmin = pd.read_csv("https://raw.githubusercontent.com/nborwankar/LearnDataScience/master/datasets/loanf.csv")

# %%
p = loansmin.boxplot('Interest.Rate','FICO.Score')
q = p.set_xticklabels(['640','','','','660','','','','680','','','','700',
  '720','','','','740','','','','760','','','','780','','','','800','','','','820','','','','840'])

q0 = p.set_xlabel('FICO Score')
q1 = p.set_ylabel('Interest Rate %')
q2 = p.set_title('                          ')

# %%
## TRY THIS!
import pandas as pd
loansmin = pd.read_csv("https://raw.githubusercontent.com/nborwankar/LearnDataScience/master/datasets/loanf.csv")
a = pd.plotting.scatter_matrix(loansmin,alpha=0.05,figsize=(10,10), diagonal='hist')

# %%
# %pylab inline
import pylab as pl
import numpy as np
#from sklearn import datasets, linear_model
import pandas as pd
import statsmodels.api as sm
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# %pylab inline
import pandas as pd
dfr = pd.read_csv("https://raw.githubusercontent.com/nborwankar/LearnDataScience/master/datasets/loanf.csv")
dfr.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000

# %%
dfr['TF']=dfr['Interest.Rate']<=12

# %%
dfr.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount     TF
# 6           15.31         670           36         4891.67         6000  False
# 11          19.72         670           36         3575.00         2000  False
# 12          14.27         665           36         4250.00        10625  False
# 13          21.67         670           60        14166.67        28000  False
# 21          21.98         665           36         6666.67        22000  False

# %%
d = dfr[dfr['Interest.Rate']==10]
d.head()
# Out:
#       Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount  \
# 650            10.0         700           36         3250.00         2800
# 204            10.0         715           36        15416.67         6000
# 440            10.0         730           36         6250.00        21000
# 521            10.0         715           36         5000.00        12000
# 1017           10.0         735           60         4000.00         5000
#
#         TF
# 650   True
# 204   True
# 440   True
# 521   True
# 1017  True

# %%
import statsmodels.api as sm
dfr['intercept']=1.0
ind_cols=['FICO.Score','Loan.Amount','intercept']
logit = sm.Logit(dfr['TF'], dfr[ind_cols])
result=logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.319503
#          Iterations 8

# %%
coeff = result.params
print(coeff)
# Out:
# FICO.Score      0.087423
# Loan.Amount    -0.000174
# intercept     -60.125045
# dtype: float64

# %%
def pz(fico, amt, coeff):
    z = coeff[0]*fico + coeff[1]*amt + coeff[2]
    return 1/(1+exp(-1*z))

# %%
pz(720,10000,coeff)
# Out:
# 0.7463785889515134

# %%
print("Trying multiple FICO Loan Amount combinations: ")
print('----')
print("fico=720, amt=10,000")
print(pz(720,10000,coeff))
print("fico=720, amt=20,000")
print(pz(720,20000,coeff))
print("fico=720, amt=30,000")
print(pz(720,30000,coeff))
print("fico=820, amt=10,000")
print(pz(820,10000,coeff))
print("fico=820, amt=20,000")
print(pz(820,20000,coeff))
print("fico=820, amt=30,000")
print(pz(820,30000,coeff))
# Out:
# Trying multiple FICO Loan Amount combinations:
# ----
# fico=720, amt=10,000
# 0.7463785889515134
# fico=720, amt=20,000
# 0.3405398576881749
# fico=720, amt=30,000
# 0.08308359523703432
# fico=820, amt=10,000
# 0.9999457423271543
# fico=820, amt=20,000
# 0.9996908677522978
# fico=820, amt=30,000
# 0.9982408301380601

# %%
pz(820,63000,coeff)
# Out:
# 0.6452511631928851

# %%
pz(820,50000,coeff)
# Out:
# 0.9458636817605445
